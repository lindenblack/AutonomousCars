# %%
"""
Using this for a guide: https://towardsdatascience.com/deeppicar-part-4-lane-following-via-opencv-737dd9e47c96
Currently working with open CV to segment road lines
"""

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import PIL 
# %matplotlib inline

# %%
frame = cv.imread(r'data\training_data\10.png')
plt.imshow(frame)
# r = int(frame[210,1])
print (r)
# Out:
# 24

# %%
red_image = PIL.Image.open(r'data\training_data\10.png')
red_image_rgb = red_image.convert("HSV")
rgb_pixel_value = red_image_rgb.getpixel((215,5))
print(rgb_pixel_value)
# Out:
# (145, 29, 60)

# %%
hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
plt.imshow(hsv)

# %%
lower_blue = np.array([0, 0, 0])
upper_blue = np.array([180, 255, 60])
mask = cv2.inRange(hsv, lower_blue, upper_blue)
plt.imshow(mask)
